# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# NOTE: make sure to change the path bellow to path to YOUR assigment folder
# %cd /content/drive/MyDrive/cs182_hw3_colab/cs182_hw3_colab/
# !pwd
# Out:
# /content/drive/MyDrive/cs182_hw3_colab/cs182_hw3_colab
# /content/drive/MyDrive/cs182_hw3_colab/cs182_hw3_colab

# %%
# !bash collect_submission.sh
# Out:
#   adding: capita.py (deflated 68%)
#   adding: language_model.py (deflated 58%)
#   adding: transformer_attention.py (deflated 73%)
#   adding: transformer.py (deflated 78%)
#   adding: transformer_utils.py (deflated 71%)
#   adding: utils.py (deflated 50%)
#   adding: 1 Language Modeling.ipynb (deflated 68%)
#   adding: 2 Summarization.ipynb (deflated 86%)
#   adding: collect_submission.ipynb (deflated 69%)
#   adding: submission_logs/ (stored 0%)
#   adding: submission_logs/build_batch.npy (deflated 93%)
#   adding: submission_logs/raw_sample_pred.npy (deflated 10%)
#   adding: submission_logs/generate_sentence.npy (deflated 76%)
#   adding: submission_logs/cosine_sim.npy (deflated 5%)
#   adding: submission_logs/multihead.npy (deflated 34%)
#   adding: submission_logs/attentionqkv.npy (deflated 34%)
#   adding: submission_logs/decoder_block.npy (deflated 34%)
#   adding: submission_logs/encoder_block.npy (deflated 33%)
#   adding: submission_logs/position_embedding.npy (deflated 34%)
#   adding: submission_logs/transformer.npy (deflated 33%)
#   adding: submission_logs/numerized2text.npy (deflated 54%)
#   adding: best_models/ (stored 0%)
#   adding: best_models/part1_best_model.pt (deflated 7%)
#   adding: best_models/part2_best_model.pt (deflated 8%)

# %%
from google.colab import files
files.download('hw3_submission.zip')
